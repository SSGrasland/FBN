# %%
#Importing libraries needed
import pandas as pd
import numpy as np

# %%
#library needed to open excel documents
"""pip install xlrd"""
# Out:
# 'pip install xlrd'

# %%
#library needed to open excel documents 
"""!pip install openpyxl"""
# Out:
# '!pip install openpyxl'

# %%
#opening the datasets
#file path 
file_name = r'C:\Users\salom\OneDrive\Área de Trabalho\FBN-\data\Feminist Bookstore News (9-5-2023).xlsx'  
sheet = "Article List"  # Specify the sheet name or number
df = pd.read_excel(io=file_name, sheet_name=sheet)

file_name = r'C:\Users\salom\OneDrive\Área de Trabalho\FBN-\data\Feminist Bookstore News (9-5-2023).xlsx'  
sheet = "Issue List"  # Specify the sheet name or number
date = pd.read_excel(io=file_name, sheet_name=sheet)

# %%
df.head()
# Out:
#   Contributor Name   Vol No    Year Month  \
# 0   Li-Anne Wright  22.0  6  2000.0   NaN
# 1   Li-Anne Wright  22.0  6  2000.0   NaN
# 2   Li-Anne Wright  22.0  6  2000.0   NaN
# 3   Li-Anne Wright  22.0  6  2000.0   NaN
# 4   Li-Anne Wright  22.0  6  2000.0   NaN
#
#                                 Article Title Page Start Page End  \
# 0                              Ms Magazine Ad          0        0
# 1                        As we go to press...          1        2
# 2         Amelia and Eleanor Go For a Ride Ad          3        3
# 3                           Winged...Words Ad          4        4
# 4  Polestar Press Gang Publishing Alliance Ad          6        6
#
#                        Author        Category Graphics? If ad, size?  \
# 0                 Ms Magazine  Advertisements       Yes          NaN
# 1                Carol Seajay   Editor's Note       NaN          NaN
# 2            Scholastic Press  Advertisements       Yes          NaN
# 3  Words Distributing Company  Advertisements       Yes          NaN
# 4         Polestar Press Gang  Advertisements       Yes          NaN
#
#                                                Notes File   @
# 0          Inner cover advertisement for Ms Magazine  NaN NaN
# 1  Commentary on B&N, FBN e-issues, Seajay in com...  NaN NaN
# 2  Advertisement for book Amelia and Eleanor Go F...  NaN NaN
# 3  Ad for Spiritual Journeys along the Yellow Bri...  NaN NaN
# 4  Advertisement for Polestar Book Publishers and...  NaN NaN

# %%
date
# Out:
#      Volume # Issue # Location Person Working on it Date Started Date Ended  \
# 0           1       1      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 1           1       2      LPA    Andréanne Wahlman   2023-08-06 2023-08-06
# 2           1       3      LPA    Andréanne Wahlman   2023-08-07 2023-08-07
# 3           1       4      LPA                  NaN          NaT        NaT
# 4           1       5      LPA                  NaN          NaT        NaT
# ..        ...     ...      ...                  ...          ...        ...
# 125        21       5    JSTOR       Li-Anne Wright   2023-05-04 2023-05-05
# 126        21       6    JSTOR       Li-Anne Wright   2023-04-28 2023-04-28
# 127        22       1    JSTOR       Li-Anne Wright   2023-04-28 2023-05-25
# 128        22     3/4    JSTOR    Andréanne Wahlman   2023-04-23 2023-06-22
# 129        22       6    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
#
#     Email Unnamed: 7 Unnamed: 8  Unnamed: 9
# 0     NaN        NaN        NaN         NaN
# 1     NaN        NaN        NaN         NaN
# 2     NaN        NaN        NaN         NaN
# 3     NaN        NaN        NaN         NaN
# 4     NaN        NaN        NaN         NaN
# ..    ...        ...        ...         ...
# 125   NaN        NaN        NaN         NaN
# 126   NaN        NaN        NaN         NaN
# 127   NaN        NaN        NaN         NaN
# 128   NaN        NaN        NaN         NaN
# 129   NaN        NaN        NaN         NaN
#
# [130 rows x 10 columns]

# %%
#renaming columns so we can join datasets 

df.rename(columns={"Vol": "Volume", "No": "Issue"}, inplace= True)
date.rename(columns={"Volume #": "Volume", "Issue #": "Issue"}, inplace =True)

# %%
#any issue that doesn't have a Date Ended means it's incomplete
#dropping any incomplete issue 
date.dropna(subset = ['Date Ended'], inplace= True)
date
# Out:
#      Volume Issue Location Person Working on it Date Started Date Ended  \
# 0         1     1      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 1         1     2      LPA    Andréanne Wahlman   2023-08-06 2023-08-06
# 2         1     3      LPA    Andréanne Wahlman   2023-08-07 2023-08-07
# 9         2     1      LPA          Rose Norman   2023-07-31 2023-07-31
# 10        2     2      LPA          Rose Norman   2023-07-31 2023-08-16
# 11        2     3      LPA          Rose Norman   2023-08-16 2023-08-16
# 12        2     4      LPA          Rose Norman   2023-08-16 2023-08-16
# 13        2   5/6      LPA          Rose Norman   2023-08-16 2023-08-16
# 14        2   7/8      LPA          Rose Norman   2023-08-16 2023-08-16
# 34        6     2      LPA    Andréanne Wahlman   2023-08-14 2023-08-14
# 37        7     1    JSTOR       Li-Anne Wright   2023-04-14 2023-05-27
# 38        7     2    JSTOR       Li-Anne Wright   2023-04-14 2023-05-27
# 39        7     3    JSTOR       Li-Anne Wright   2023-04-14 2023-05-27
# 40        7     4    JSTOR       Li-Anne Wright   2023-04-14 2023-05-27
# 41        7     5    JSTOR         Cassidy Hunt   2023-04-28 2023-04-28
# 42        7     6    JSTOR         Cassidy Hunt   2023-04-28 2023-04-28
# 44        8   2/3    JSTOR         Rosal Lorico   2023-05-14 2023-06-18
# 45        8     4    JSTOR         Cassidy Hunt   2023-05-15 2023-05-15
# 46        8     5    JSTOR         Chloe Berger   2023-05-18 2023-05-18
# 47        8     6    JSTOR         Chloe Berger   2023-05-18 2023-05-21
# 48        9     1    JSTOR         Chloe Berger   2023-05-31 2023-05-31
# 49        9   3/4    JSTOR         Chloe Berger   2023-06-04 2023-06-05
# 50        9     5    JSTOR          Anna Greene   2023-06-08 2023-07-02
# 51        9     6    JSTOR         Cassidy Hunt   2023-11-06 2023-07-24
# 52       10     2    JSTOR         Julie Enszer   2023-06-12 2023-06-18
# 53       10     3    JSTOR       Li-Anne Wright   2023-06-14 2023-07-31
# 54       10     4    JSTOR         Rosal Lorico   2023-06-18 2023-07-05
# 55       10     5    JSTOR    Andréanne Wahlman   2023-06-23 2023-06-30
# 56       10     6    JSTOR       Li-Anne Wright   2023-06-12 2023-06-14
# 58       11     2    JSTOR         Taylor Humin   2023-06-24 2023-07-16
# 59       11     3    JSTOR    Andréanne Wahlman   2023-06-30 2023-07-07
# 60       11     4    JSTOR       Taylor Harding   2023-06-24 2024-08-13
# 61       11     5    JSTOR          Ana A. Rico   2023-07-01 2023-07-27
# 62       11     6    JSTOR   Elizabeth Galoozis   2023-07-02 2023-08-13
# 63       12     1    JSTOR         Rosal Lorico   2023-07-05 2023-07-22
# 65       12     3    JSTOR     Elizabeth Lanyon   2023-07-07 2023-07-10
# 66       12     4    JSTOR    Andréanne Wahlman   2023-07-07 2023-07-22
# 71       13     2    JSTOR     Elizabeth Lanyon   2023-07-11 2023-07-14
# 72       13     3    JSTOR     Elizabeth Lanyon   2023-08-09 2023-08-25
# 74       13     5    JSTOR         Nicole Olila   2023-05-26 2023-07-28
# 75       13     6    JSTOR         Cassidy Hunt   2023-07-31 2023-08-22
# 93       16     3    JSTOR    Dana Westmoreland   2023-07-26 2023-08-26
# 104      18     1    JSTOR         Taylor Humin   2023-07-21 2023-09-04
# 116      19     6    JSTOR       Alexa Mangione   2023-07-17 2023-08-21
# 119      20     4    JSTOR         Sam Grasland   2023-07-26 2023-08-13
# 121      21     1    JSTOR         Sam Grasland   2023-05-28 2023-07-21
# 125      21     5    JSTOR       Li-Anne Wright   2023-05-04 2023-05-05
# 126      21     6    JSTOR       Li-Anne Wright   2023-04-28 2023-04-28
# 127      22     1    JSTOR       Li-Anne Wright   2023-04-28 2023-05-25
# 128      22   3/4    JSTOR    Andréanne Wahlman   2023-04-23 2023-06-22
# 129      22     6    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
#
#                                                  Email Unnamed: 7  \
# 0                                                  NaN        NaN
# 1                                                  NaN        NaN
# 2                                                  NaN        NaN
# 9                                rose.norman@gmail.com        NaN
# 10                               rose.norman@gmail.com        NaN
# 11                               rose.norman@gmail.com        NaN
# 12                               rose.norman@gmail.com        NaN
# 13                               rose.norman@gmail.com        NaN
# 14                               rose.norman@gmail.com        NaN
# 34                                                 NaN        NaN
# 37                                                 NaN        NaN
# 38                                                 NaN        NaN
# 39                                                 NaN        NaN
# 40                                                 NaN        NaN
# 41                                                 NaN        NaN
# 42                                                 NaN        NaN
# 44                                                 NaN        NaN
# 45                                                 NaN        NaN
# 46                                                 NaN        NaN
# 47                                                 NaN        NaN
# 48                                                 NaN        NaN
# 49                                                 NaN        NaN
# 50                                                 NaN        NaN
# 51                                                 NaN        NaN
# 52                                                 NaN        NaN
# 53                                                 NaN        NaN
# 54                                                 NaN        NaN
# 55                                                 NaN        NaN
# 56                                                 NaN        NaN
# 58                                                 NaN        NaN
# 59                                                 NaN        NaN
# 60                          taylor.harding88@gmail.com        NaN
# 61                              ana.a.rico44@gmail.com        NaN
# 62                                                 NaN        NaN
# 63                                                 NaN        NaN
# 65                                e.m.lanyon@gmail.com        NaN
# 66                                                 NaN        NaN
# 71                                e.m.lanyon@gmail.com        NaN
# 72                                e.m.lanyon@gmail.com        NaN
# 74   NOTE: Cassidy Hunt started on 7/26/2023 - (thi...        NaN
# 75                                                 NaN        NaN
# 93                             midd.west2013@gmail.com        NaN
# 104                              taylorhumin@gmail.com        NaN
# 116                           mangione.alexa@gmail.com        NaN
# 119                              samgrasland@gmail.com        NaN
# 121                              samgrasland@gmail.com        NaN
# 125                                                NaN        NaN
# 126                                                NaN        NaN
# 127                                                NaN        NaN
# 128                                                NaN        NaN
# 129                                                NaN        NaN
#
#       Unnamed: 8  Unnamed: 9
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 34           NaN         NaN
# 37   In progress        10.0
# 38     Completed        51.0
# 39           NaN         NaN
# 40           NaN         NaN
# 41           NaN         NaN
# 42           NaN         NaN
# 44           NaN         NaN
# 45           NaN         NaN
# 46           NaN         NaN
# 47           NaN         NaN
# 48           NaN         NaN
# 49           NaN         NaN
# 50           NaN         NaN
# 51           NaN         NaN
# 52           NaN         NaN
# 53           NaN         NaN
# 54           NaN         NaN
# 55           NaN         NaN
# 56           NaN         NaN
# 58           NaN         NaN
# 59           NaN         NaN
# 60           NaN         NaN
# 61           NaN         NaN
# 62           NaN         NaN
# 63           NaN         NaN
# 65           NaN         NaN
# 66           NaN         NaN
# 71           NaN         NaN
# 72           NaN         NaN
# 74           NaN         NaN
# 75           NaN         NaN
# 93           NaN         NaN
# 104          NaN         NaN
# 116          NaN         NaN
# 119          NaN         NaN
# 121          NaN         NaN
# 125          NaN         NaN
# 126          NaN         NaN
# 127          NaN         NaN
# 128          NaN         NaN
# 129          NaN         NaN

# %%
df['Volume'] = pd.to_numeric(df['Volume'], errors='coerce')
df['Issue'] = pd.to_numeric(df['Issue'], errors='coerce')
date['Volume'] = pd.to_numeric(date['Volume'], errors='coerce')
date['Issue'] = pd.to_numeric(date['Issue'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2296 entries, 0 to 2295
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contributor Name  2267 non-null   object
#  1   Volume            2267 non-null   float64
#  2   Issue             2057 non-null   float64
#  3   Year              2267 non-null   float64
#  4   Month             1647 non-null   object
#  5   Article Title     2194 non-null   object
#  6   Page Start        2214 non-null   object
#  7   Page End          2176 non-null   object
#  8   Author            2007 non-null   object
#  9   Category          2189 non-null   object
#  10  Graphics?         1434 non-null   object
#  11  If ad, size?      201 non-null    object
#  12  Notes             1314 non-null   object
#  13  File              3 non-null      object
#  14  @                 0 non-null      float64
# dtypes: float64(4), object(11)
# memory usage: 269.2+ KB

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 129
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Volume                51 non-null     int64
#  1   Issue                 46 non-null     float64
#  2   Location              51 non-null     object
#  3   Person Working on it  51 non-null     object
#  4   Date Started          51 non-null     datetime64[ns]
#  5   Date Ended            51 non-null     datetime64[ns]
#  6   Email                 17 non-null     object
#  7   Unnamed: 7            0 non-null      object
#  8   Unnamed: 8            2 non-null      object
#  9   Unnamed: 9            2 non-null      float64
# dtypes: datetime64[ns](2), float64(2), int64(1), object(5)
# memory usage: 4.4+ KB

# %%
#joining the datasets date and df so we can drop any info from df that is incomplete
#setting the index to Volume and Issue so that we use .join()
df.set_index(['Volume', 'Issue'], inplace = True)
date.set_index(['Volume', 'Issue'], inplace = True)

# %%
df.head()
# Out:
#              Contributor Name    Year Month  \
# Volume Issue
# 22.0   6.0     Li-Anne Wright  2000.0   NaN
#        6.0     Li-Anne Wright  2000.0   NaN
#        6.0     Li-Anne Wright  2000.0   NaN
#        6.0     Li-Anne Wright  2000.0   NaN
#        6.0     Li-Anne Wright  2000.0   NaN
#
#                                            Article Title Page Start Page End  \
# Volume Issue
# 22.0   6.0                                Ms Magazine Ad          0        0
#        6.0                          As we go to press...          1        2
#        6.0           Amelia and Eleanor Go For a Ride Ad          3        3
#        6.0                             Winged...Words Ad          4        4
#        6.0    Polestar Press Gang Publishing Alliance Ad          6        6
#
#                                   Author        Category Graphics?  \
# Volume Issue
# 22.0   6.0                   Ms Magazine  Advertisements       Yes
#        6.0                  Carol Seajay   Editor's Note       NaN
#        6.0              Scholastic Press  Advertisements       Yes
#        6.0    Words Distributing Company  Advertisements       Yes
#        6.0           Polestar Press Gang  Advertisements       Yes
#
#              If ad, size?                                              Notes  \
# Volume Issue
# 22.0   6.0            NaN          Inner cover advertisement for Ms Magazine
#        6.0            NaN  Commentary on B&N, FBN e-issues, Seajay in com...
#        6.0            NaN  Advertisement for book Amelia and Eleanor Go F...
#        6.0            NaN  Ad for Spiritual Journeys along the Yellow Bri...
#        6.0            NaN  Advertisement for Polestar Book Publishers and...
#
#              File   @
# Volume Issue
# 22.0   6.0    NaN NaN
#        6.0    NaN NaN
#        6.0    NaN NaN
#        6.0    NaN NaN
#        6.0    NaN NaN

# %%
date.head()
# Out:
#              Location Person Working on it Date Started Date Ended  \
# Volume Issue
# 1      1.0        LPA       Li-Anne Wright   2023-07-22 2023-07-23
#        2.0        LPA    Andréanne Wahlman   2023-08-06 2023-08-06
#        3.0        LPA    Andréanne Wahlman   2023-08-07 2023-08-07
# 2      1.0        LPA          Rose Norman   2023-07-31 2023-07-31
#        2.0        LPA          Rose Norman   2023-07-31 2023-08-16
#
#                               Email Unnamed: 7 Unnamed: 8  Unnamed: 9
# Volume Issue
# 1      1.0                      NaN        NaN        NaN         NaN
#        2.0                      NaN        NaN        NaN         NaN
#        3.0                      NaN        NaN        NaN         NaN
# 2      1.0    rose.norman@gmail.com        NaN        NaN         NaN
#        2.0    rose.norman@gmail.com        NaN        NaN         NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 2296 entries, (22.0, 6.0) to (14.0, 1.0)
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Contributor Name  2267 non-null   object
#  1   Year              2267 non-null   float64
#  2   Month             1647 non-null   object
#  3   Article Title     2194 non-null   object
#  4   Page Start        2214 non-null   object
#  5   Page End          2176 non-null   object
#  6   Author            2007 non-null   object
#  7   Category          2189 non-null   object
#  8   Graphics?         1434 non-null   object
#  9   If ad, size?      201 non-null    object
#  10  Notes             1314 non-null   object
#  11  File              3 non-null      object
#  12  @                 0 non-null      float64
# dtypes: float64(2), object(11)
# memory usage: 238.7+ KB

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 51 entries, (1, 1.0) to (22, 6.0)
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Location              51 non-null     object
#  1   Person Working on it  51 non-null     object
#  2   Date Started          51 non-null     datetime64[ns]
#  3   Date Ended            51 non-null     datetime64[ns]
#  4   Email                 17 non-null     object
#  5   Unnamed: 7            0 non-null      object
#  6   Unnamed: 8            2 non-null      object
#  7   Unnamed: 9            2 non-null      float64
# dtypes: datetime64[ns](2), float64(1), object(5)
# memory usage: 4.3+ KB

# %%
#joining df and date datasets
df = date.join(df, how='left')

# %%
#reseting the index
df.reset_index(inplace = True)
df.head()
# Out:
#    Volume  Issue Location Person Working on it Date Started Date Ended Email  \
# 0       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 1       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 2       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 3       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 4       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
#
#   Unnamed: 7 Unnamed: 8  Unnamed: 9  ...             Article Title  \
# 0        NaN        NaN         NaN  ...  Mission/About Newsletter
# 1        NaN        NaN         NaN  ...            Editor's Note?
# 2        NaN        NaN         NaN  ...             Hot New Books
# 3        NaN        NaN         NaN  ...          Books in Spanish
# 4        NaN        NaN         NaN  ...           Brilliant Ideas
#
#    Page Start Page End        Author               Category Graphics?  \
# 0           1        1         Andre          Editor's Note       NaN
# 1           2        2  Carol Seajay          Editor's Note       NaN
# 2           2        3  Carol Seajay     Booklist/Medialist       NaN
# 3           3        5  Carol Seajay     Booklist/Medialist       NaN
# 4           5        5  Carol Seajay  Short News Bookstores       NaN
#
#   If ad, size?                                              Notes File   @
# 0          NaN  Mission of FBN (share info, cooperate instead ...  NaN NaN
# 1          NaN                                                NaN  NaN NaN
# 2          NaN                                                NaN  NaN NaN
# 3          NaN                                                NaN  NaN NaN
# 4          NaN                                                NaN  NaN NaN
#
# [5 rows x 23 columns]

# %%
#any issue that doesn't have a Date Ended means it's incomplete
#dropping any incomplete issue 
df.dropna(subset = ['Date Ended'], inplace= True)
df
# Out:
#       Volume  Issue Location Person Working on it Date Started Date Ended  \
# 0          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 1          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 2          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 3          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 4          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# ...      ...    ...      ...                  ...          ...        ...
# 2059      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2060      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2061      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2062      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2063      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
#
#      Email Unnamed: 7 Unnamed: 8  Unnamed: 9  ...  \
# 0      NaN        NaN        NaN         NaN  ...
# 1      NaN        NaN        NaN         NaN  ...
# 2      NaN        NaN        NaN         NaN  ...
# 3      NaN        NaN        NaN         NaN  ...
# 4      NaN        NaN        NaN         NaN  ...
# ...    ...        ...        ...         ...  ...
# 2059   NaN        NaN        NaN         NaN  ...
# 2060   NaN        NaN        NaN         NaN  ...
# 2061   NaN        NaN        NaN         NaN  ...
# 2062   NaN        NaN        NaN         NaN  ...
# 2063   NaN        NaN        NaN         NaN  ...
#
#                             Article Title  Page Start Page End  \
# 0                Mission/About Newsletter           1        1
# 1                          Editor's Note?           2        2
# 2                           Hot New Books           2        3
# 3                        Books in Spanish           3        5
# 4                         Brilliant Ideas           5        5
# ...                                   ...         ...      ...
# 2059            Celebrate Our Strength ad         116      116
# 2060               And On Publisher's Row         117      135
# 2061                 Index of Advertisers         136      136
# 2062             The Naiad Press, Inc. ad         137      137
# 2063  Women Writing a Feminist Future! ad         139      139
#
#                      Author               Category Graphics? If ad, size?  \
# 0                     Andre          Editor's Note       NaN          NaN
# 1              Carol Seajay          Editor's Note       NaN          NaN
# 2              Carol Seajay     Booklist/Medialist       NaN          NaN
# 3              Carol Seajay     Booklist/Medialist       NaN          NaN
# 4              Carol Seajay  Short News Bookstores       NaN          NaN
# ...                     ...                    ...       ...          ...
# 2059                 Bantam         Advertisements       Yes          NaN
# 2060      Teri Mae Rutledge              Presslist       Yes          NaN
# 2061                    FBN                  Other       NaN          NaN
# 2062  The Naiad Press, Inc.         Advertisements       Yes          NaN
# 2063          Spinsters Ink         Advertisements       Yes          NaN
#
#                                                   Notes File   @
# 0     Mission of FBN (share info, cooperate instead ...  NaN NaN
# 1                                                   NaN  NaN NaN
# 2                                                   NaN  NaN NaN
# 3                                                   NaN  NaN NaN
# 4                                                   NaN  NaN NaN
# ...                                                 ...  ...  ..
# 2059  Ad for Circle Round by Starhawk, Dianne Baker,...  NaN NaN
# 2060  Graphics: Bantam Trade Paperback ad for barbar...  NaN NaN
# 2061                                                NaN  NaN NaN
# 2062  Ad for Unforgettable by Karin Kallmaker and Un...  NaN NaN
# 2063  Ad for Booked for Murder by Val McDermid; Thos...  NaN NaN
#
# [2064 rows x 23 columns]

# %%
#dropping all 'Unnamed' columns
# Create a boolean array indicating which columns contain the string "Unnamed"
cols_to_drop = df.columns[df.columns.str.contains('Unnamed')]

# Drop the columns containing the string "Email"
df.drop(cols_to_drop, axis=1, inplace=True)
df
# Out:
#       Volume  Issue Location Person Working on it Date Started Date Ended  \
# 0          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 1          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 2          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 3          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 4          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# ...      ...    ...      ...                  ...          ...        ...
# 2059      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2060      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2061      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2062      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2063      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
#
#      Email Contributor Name    Year    Month  \
# 0      NaN   Li-Anne Wright  1976.0  October
# 1      NaN   Li-Anne Wright  1976.0  October
# 2      NaN   Li-Anne Wright  1976.0  October
# 3      NaN   Li-Anne Wright  1976.0  October
# 4      NaN   Li-Anne Wright  1976.0  October
# ...    ...              ...     ...      ...
# 2059   NaN   Li-Anne Wright  2000.0      NaN
# 2060   NaN   Li-Anne Wright  2000.0      NaN
# 2061   NaN   Li-Anne Wright  2000.0      NaN
# 2062   NaN   Li-Anne Wright  2000.0      NaN
# 2063   NaN   Li-Anne Wright  2000.0      NaN
#
#                             Article Title Page Start Page End  \
# 0                Mission/About Newsletter          1        1
# 1                          Editor's Note?          2        2
# 2                           Hot New Books          2        3
# 3                        Books in Spanish          3        5
# 4                         Brilliant Ideas          5        5
# ...                                   ...        ...      ...
# 2059            Celebrate Our Strength ad        116      116
# 2060               And On Publisher's Row        117      135
# 2061                 Index of Advertisers        136      136
# 2062             The Naiad Press, Inc. ad        137      137
# 2063  Women Writing a Feminist Future! ad        139      139
#
#                      Author               Category Graphics? If ad, size?  \
# 0                     Andre          Editor's Note       NaN          NaN
# 1              Carol Seajay          Editor's Note       NaN          NaN
# 2              Carol Seajay     Booklist/Medialist       NaN          NaN
# 3              Carol Seajay     Booklist/Medialist       NaN          NaN
# 4              Carol Seajay  Short News Bookstores       NaN          NaN
# ...                     ...                    ...       ...          ...
# 2059                 Bantam         Advertisements       Yes          NaN
# 2060      Teri Mae Rutledge              Presslist       Yes          NaN
# 2061                    FBN                  Other       NaN          NaN
# 2062  The Naiad Press, Inc.         Advertisements       Yes          NaN
# 2063          Spinsters Ink         Advertisements       Yes          NaN
#
#                                                   Notes File   @
# 0     Mission of FBN (share info, cooperate instead ...  NaN NaN
# 1                                                   NaN  NaN NaN
# 2                                                   NaN  NaN NaN
# 3                                                   NaN  NaN NaN
# 4                                                   NaN  NaN NaN
# ...                                                 ...  ...  ..
# 2059  Ad for Circle Round by Starhawk, Dianne Baker,...  NaN NaN
# 2060  Graphics: Bantam Trade Paperback ad for barbar...  NaN NaN
# 2061                                                NaN  NaN NaN
# 2062  Ad for Unforgettable by Karin Kallmaker and Un...  NaN NaN
# 2063  Ad for Booked for Murder by Val McDermid; Thos...  NaN NaN
#
# [2064 rows x 20 columns]

# %%
df[['Page Start', 'Page End', 'Volume']] = df[['Page Start', 'Page End', 'Volume']].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2064 entries, 0 to 2063
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Volume                2064 non-null   int64
#  1   Issue                 1816 non-null   float64
#  2   Location              2064 non-null   object
#  3   Person Working on it  2064 non-null   object
#  4   Date Started          2064 non-null   datetime64[ns]
#  5   Date Ended            2064 non-null   datetime64[ns]
#  6   Email                 952 non-null    object
#  7   Contributor Name      2064 non-null   object
#  8   Year                  2064 non-null   float64
#  9   Month                 1493 non-null   object
#  10  Article Title         2051 non-null   object
#  11  Page Start            2031 non-null   float64
#  12  Page End              1989 non-null   float64
#  13  Author                1896 non-null   object
#  14  Category              2041 non-null   object
#  15  Graphics?             1352 non-null   object
#  16  If ad, size?          163 non-null    object
#  17  Notes                 1190 non-null   object
#  18  File                  3 non-null      object
#  19  @                     0 non-null      float64
# dtypes: datetime64[ns](2), float64(5), int64(1), object(12)
# memory usage: 322.6+ KB

# %%
df['Issue Length'] = df.groupby(['Volume', 'Issue'])['Page End'].transform(max)

# %%
df
# Out:
#       Volume  Issue Location Person Working on it Date Started Date Ended  \
# 0          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 1          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 2          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 3          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# 4          1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23
# ...      ...    ...      ...                  ...          ...        ...
# 2059      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2060      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2061      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2062      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
# 2063      22    6.0    JSTOR       Li-Anne Wright   2023-04-14 2023-04-14
#
#      Email Contributor Name    Year    Month  ... Page Start  Page End  \
# 0      NaN   Li-Anne Wright  1976.0  October  ...        1.0       1.0
# 1      NaN   Li-Anne Wright  1976.0  October  ...        2.0       2.0
# 2      NaN   Li-Anne Wright  1976.0  October  ...        2.0       3.0
# 3      NaN   Li-Anne Wright  1976.0  October  ...        3.0       5.0
# 4      NaN   Li-Anne Wright  1976.0  October  ...        5.0       5.0
# ...    ...              ...     ...      ...  ...        ...       ...
# 2059   NaN   Li-Anne Wright  2000.0      NaN  ...      116.0     116.0
# 2060   NaN   Li-Anne Wright  2000.0      NaN  ...      117.0     135.0
# 2061   NaN   Li-Anne Wright  2000.0      NaN  ...      136.0     136.0
# 2062   NaN   Li-Anne Wright  2000.0      NaN  ...      137.0     137.0
# 2063   NaN   Li-Anne Wright  2000.0      NaN  ...      139.0     139.0
#
#                      Author               Category Graphics? If ad, size?  \
# 0                     Andre          Editor's Note       NaN          NaN
# 1              Carol Seajay          Editor's Note       NaN          NaN
# 2              Carol Seajay     Booklist/Medialist       NaN          NaN
# 3              Carol Seajay     Booklist/Medialist       NaN          NaN
# 4              Carol Seajay  Short News Bookstores       NaN          NaN
# ...                     ...                    ...       ...          ...
# 2059                 Bantam         Advertisements       Yes          NaN
# 2060      Teri Mae Rutledge              Presslist       Yes          NaN
# 2061                    FBN                  Other       NaN          NaN
# 2062  The Naiad Press, Inc.         Advertisements       Yes          NaN
# 2063          Spinsters Ink         Advertisements       Yes          NaN
#
#                                                   Notes File   @  Issue Length
# 0     Mission of FBN (share info, cooperate instead ...  NaN NaN           8.0
# 1                                                   NaN  NaN NaN           8.0
# 2                                                   NaN  NaN NaN           8.0
# 3                                                   NaN  NaN NaN           8.0
# 4                                                   NaN  NaN NaN           8.0
# ...                                                 ...  ...  ..           ...
# 2059  Ad for Circle Round by Starhawk, Dianne Baker,...  NaN NaN         139.0
# 2060  Graphics: Bantam Trade Paperback ad for barbar...  NaN NaN         139.0
# 2061                                                NaN  NaN NaN         139.0
# 2062  Ad for Unforgettable by Karin Kallmaker and Un...  NaN NaN         139.0
# 2063  Ad for Booked for Murder by Val McDermid; Thos...  NaN NaN         139.0
#
# [2064 rows x 21 columns]

# %%
df['Article Length'] = (df['Page End'] - df['Page Start']) + 1
df.head()
# Out:
#    Volume  Issue Location Person Working on it Date Started Date Ended Email  \
# 0       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 1       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 2       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 3       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 4       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
#
#   Contributor Name    Year    Month  ... Page End        Author  \
# 0   Li-Anne Wright  1976.0  October  ...      1.0         Andre
# 1   Li-Anne Wright  1976.0  October  ...      2.0  Carol Seajay
# 2   Li-Anne Wright  1976.0  October  ...      3.0  Carol Seajay
# 3   Li-Anne Wright  1976.0  October  ...      5.0  Carol Seajay
# 4   Li-Anne Wright  1976.0  October  ...      5.0  Carol Seajay
#
#                 Category Graphics? If ad, size?  \
# 0          Editor's Note       NaN          NaN
# 1          Editor's Note       NaN          NaN
# 2     Booklist/Medialist       NaN          NaN
# 3     Booklist/Medialist       NaN          NaN
# 4  Short News Bookstores       NaN          NaN
#
#                                                Notes File   @ Issue Length  \
# 0  Mission of FBN (share info, cooperate instead ...  NaN NaN          8.0
# 1                                                NaN  NaN NaN          8.0
# 2                                                NaN  NaN NaN          8.0
# 3                                                NaN  NaN NaN          8.0
# 4                                                NaN  NaN NaN          8.0
#
#    Article Length
# 0             1.0
# 1             1.0
# 2             2.0
# 3             3.0
# 4             1.0
#
# [5 rows x 22 columns]

# %%
df['Article Percent'] = (df['Article Length']/df['Issue Length'])*100

# %%
df.head()
# Out:
#    Volume  Issue Location Person Working on it Date Started Date Ended Email  \
# 0       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 1       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 2       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 3       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
# 4       1    1.0      LPA       Li-Anne Wright   2023-07-22 2023-07-23   NaN
#
#   Contributor Name    Year    Month  ...        Author               Category  \
# 0   Li-Anne Wright  1976.0  October  ...         Andre          Editor's Note
# 1   Li-Anne Wright  1976.0  October  ...  Carol Seajay          Editor's Note
# 2   Li-Anne Wright  1976.0  October  ...  Carol Seajay     Booklist/Medialist
# 3   Li-Anne Wright  1976.0  October  ...  Carol Seajay     Booklist/Medialist
# 4   Li-Anne Wright  1976.0  October  ...  Carol Seajay  Short News Bookstores
#
#    Graphics? If ad, size?                                              Notes  \
# 0        NaN          NaN  Mission of FBN (share info, cooperate instead ...
# 1        NaN          NaN                                                NaN
# 2        NaN          NaN                                                NaN
# 3        NaN          NaN                                                NaN
# 4        NaN          NaN                                                NaN
#
#   File   @ Issue Length Article Length  Article Percent
# 0  NaN NaN          8.0            1.0             12.5
# 1  NaN NaN          8.0            1.0             12.5
# 2  NaN NaN          8.0            2.0             25.0
# 3  NaN NaN          8.0            3.0             37.5
# 4  NaN NaN          8.0            1.0             12.5
#
# [5 rows x 23 columns]

# %%
df = df[['Contributor Name', 'Volume', 'Issue', 'Year', 'Month', 'Article Title', 'Page Start', 'Page End', 'Article Length', 'Article Percent', 'Issue Length', 'Date Started', 'Date Ended', 'Author', 'Category', 'Graphics?', 'Notes', 'File']]
df.head()
# Out:
#   Contributor Name  Volume  Issue    Year    Month             Article Title  \
# 0   Li-Anne Wright       1    1.0  1976.0  October  Mission/About Newsletter
# 1   Li-Anne Wright       1    1.0  1976.0  October            Editor's Note?
# 2   Li-Anne Wright       1    1.0  1976.0  October             Hot New Books
# 3   Li-Anne Wright       1    1.0  1976.0  October          Books in Spanish
# 4   Li-Anne Wright       1    1.0  1976.0  October           Brilliant Ideas
#
#    Page Start  Page End  Article Length  Article Percent  Issue Length  \
# 0         1.0       1.0             1.0             12.5           8.0
# 1         2.0       2.0             1.0             12.5           8.0
# 2         2.0       3.0             2.0             25.0           8.0
# 3         3.0       5.0             3.0             37.5           8.0
# 4         5.0       5.0             1.0             12.5           8.0
#
#   Date Started Date Ended        Author               Category Graphics?  \
# 0   2023-07-22 2023-07-23         Andre          Editor's Note       NaN
# 1   2023-07-22 2023-07-23  Carol Seajay          Editor's Note       NaN
# 2   2023-07-22 2023-07-23  Carol Seajay     Booklist/Medialist       NaN
# 3   2023-07-22 2023-07-23  Carol Seajay     Booklist/Medialist       NaN
# 4   2023-07-22 2023-07-23  Carol Seajay  Short News Bookstores       NaN
#
#                                                Notes File
# 0  Mission of FBN (share info, cooperate instead ...  NaN
# 1                                                NaN  NaN
# 2                                                NaN  NaN
# 3                                                NaN  NaN
# 4                                                NaN  NaN

# %%
df.Month.unique()
# Out:
# array(['October', 'November', 'January', '?', 'June', 'August',
#        '(Sep/Oct?)', 'December', 'September', nan, 'May-June', 'Dec',
#        'Feb', 'April', 'Augusr', 'Nov/Dec.', 'Nov', 'Jan/Feb', 'Mar/Apr',
#        'May/June', 'Sept / Oct', 'Sept/Oct', 'March/April',
#        'November/December', 3], dtype=object)

# %%
#Unifying Month Values 
row_labels = {'(Sep/Oct?)':'September','May-June':'May', 'Dec':'December',
       'Feb':'February', 'Augusr':'August', 'Nov/Dec.':'November', 'Nov':'November', 'Jan/Feb':'January', 'Mar/Apr':'March',
       'May/June':'May', 'Sept / Oct':'September', 'Sept/Oct':'September', 'March/April':'March',
       'November/December':'November'}

df['Month']=df['Month'].replace(row_labels)
# Out:
# C:\Users\salom\AppData\Local\Temp\ipykernel_9112\1502239364.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month']=df['Month'].replace(row_labels)

# %%
df.Month.unique()
# Out:
# array(['October', 'November', 'January', '?', 'June', 'August',
#        'September', 'December', nan, 'May', 'February', 'April', 'March',
#        3], dtype=object)

# %%
df.Category.unique()
# Out:
# array(["Editor's Note", 'Booklist/Medialist', 'Short News Bookstores',
#        'Other', 'Other Feature', 'Advertisements', 'Table of Contents',
#        'Letters', 'News Feature', 'Short News', nan,
#        'External Booklists and Awards', 'Short News Publishers',
#        'They Went That-A-Way', 'Letter ', 'Booklist/Media list',
#        'Workshop Summary', 'Presslist', 'Writing Wanted', 'Booklist'],
#       dtype=object)

# %%
row_labels = {'Other Feature' : 'Other', 'Letter ':'Letters', 'Booklist/Media list' : 'Booklist/Medialist', 'Booklist':'Booklist/Medialist'}

df['Category']=df['Category'].replace(row_labels)
# Out:
# C:\Users\salom\AppData\Local\Temp\ipykernel_9112\165856882.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category']=df['Category'].replace(row_labels)

# %%
df.Category.unique()
# Out:
# array(["Editor's Note", 'Booklist/Medialist', 'Short News Bookstores',
#        'Other', 'Advertisements', 'Table of Contents', 'Letters',
#        'News Feature', 'Short News', nan, 'External Booklists and Awards',
#        'Short News Publishers', 'They Went That-A-Way',
#        'Workshop Summary', 'Presslist', 'Writing Wanted'], dtype=object)

# %%
df[df['Category'].isna()]
# Out:
#        Contributor Name  Volume  Issue    Year     Month  \
# 36          Rose Norman       2    1.0  1978.0         ?
# 37          Rose Norman       2    1.0  1978.0         ?
# 40          Rose Norman       2    1.0  1978.0         ?
# 41          Rose Norman       2    1.0  1978.0         ?
# 42          Rose Norman       2    1.0  1978.0         ?
# 43          Rose Norman       2    1.0  1978.0         ?
# 397        Cassidy Hunt       8    4.0  1985.0       NaN
# 471        Chloe Berger       9    NaN  1987.0       NaN
# 573      Julie R Enszer      10    2.0  1987.0    August
# 759      Li-Anne Wright      10    6.0  1988.0     April
# 894      Taylor Harding      11    4.0  1988.0  November
# 1048       Rosal Lorico      12    1.0  1989.0       May
# 1049       Rosal Lorico      12    1.0  1989.0       May
# 1050       Rosal Lorico      12    1.0  1989.0       May
# 1051       Rosal Lorico      12    1.0  1989.0       May
# 1052       Rosal Lorico      12    1.0  1989.0       May
# 1183   Elizabeth Lanyon      13    2.0  1990.0    August
# 1248   Elizabeth Lanyon      13    3.0  1990.0   October
# 1260   Elizabeth Lanyon      13    3.0  1990.0   October
# 1267   Elizabeth Lanyon      13    3.0  1990.0   October
# 1270   Elizabeth Lanyon      13    3.0  1990.0   October
# 1439  Dana Westmoreland      16    3.0  1993.0   October
# 1504         Theo Baker      18    1.0  1995.0       May
#
#                                           Article Title  Page Start  Page End  \
# 36                                        From the Boys         9.0       NaN
# 37                                          SciFi Notes        10.0       NaN
# 40                                           Used Books        11.0       NaN
# 41                                     New Distributors        11.0       NaN
# 42                         Misc from the Questionnaires        12.0       NaN
# 43                                             Changing        12.0       NaN
# 397                                  On Publisher's Row        46.0      52.0
# 471                                Customary Treatment?        17.0      17.0
# 573                               Tupperware Watch OUT!        16.0       NaN
# 759                                             Letters         4.0      64.0
# 894                                      Short Stories         17.0      20.0
# 1048                                        Bestsellers        23.0       NaN
# 1049                                                NaN         NaN       NaN
# 1050                                                NaN         NaN       NaN
# 1051                                                NaN         NaN       NaN
# 1052                                                NaN         NaN       NaN
# 1183                            Feminist Bookstore News         0.0       0.0
# 1248                       The Fall Announcements Issue         0.0       0.0
# 1260                In Moscow: A Lesbian Feminist Press        15.0      17.0
# 1267  But Can She Type?  Earth-Conscious Feminst Boo...        25.0      26.0
# 1270                                                NaN        28.0      28.0
# 1439                                     Writing Wanted        63.0      64.0
# 1504  The American Family is Changing. Is this bad? ...         3.0       3.0
#
#       Article Length  Article Percent  Issue Length Date Started Date Ended  \
# 36               NaN              NaN           6.0   2023-07-31 2023-07-31
# 37               NaN              NaN           6.0   2023-07-31 2023-07-31
# 40               NaN              NaN           6.0   2023-07-31 2023-07-31
# 41               NaN              NaN           6.0   2023-07-31 2023-07-31
# 42               NaN              NaN           6.0   2023-07-31 2023-07-31
# 43               NaN              NaN           6.0   2023-07-31 2023-07-31
# 397              7.0        13.461538          52.0   2023-05-15 2023-05-15
# 471              1.0              NaN           NaN   2023-06-04 2023-06-05
# 573              NaN              NaN          82.0   2023-06-12 2023-06-18
# 759             61.0        92.424242          66.0   2023-06-12 2023-06-14
# 894              4.0         4.000000         100.0   2023-06-24 2024-08-13
# 1048             NaN              NaN          22.0   2023-07-05 2023-07-22
# 1049             NaN              NaN          22.0   2023-07-05 2023-07-22
# 1050             NaN              NaN          22.0   2023-07-05 2023-07-22
# 1051             NaN              NaN          22.0   2023-07-05 2023-07-22
# 1052             NaN              NaN          22.0   2023-07-05 2023-07-22
# 1183             1.0         1.086957          92.0   2023-07-11 2023-07-14
# 1248             1.0         0.806452         124.0   2023-08-09 2023-08-25
# 1260             3.0         2.419355         124.0   2023-08-09 2023-08-25
# 1267             2.0         1.612903         124.0   2023-08-09 2023-08-25
# 1270             1.0         0.806452         124.0   2023-08-09 2023-08-25
# 1439             2.0         1.515152         132.0   2023-07-26 2023-08-26
# 1504             1.0         0.735294         136.0   2023-07-21 2023-09-04
#
#                                                  Author Category  \
# 36                                                  NaN      NaN
# 37                                                  NaN      NaN
# 40                       Sonya Wetstone's Book & Cheese      NaN
# 41                                                  NaN      NaN
# 42                                                  NaN      NaN
# 43                                         Carol Seajay      NaN
# 397                                                 NaN      NaN
# 471       GCN, The London Gay Times, British Bookseller      NaN
# 573                           Peggy & Womanspirit Books      NaN
# 759   Jahnet Hewsick; Gail (The Feminist Bookshop); ...      NaN
# 894                                                 NaN      NaN
# 1048  New Words, Pandora Book Peddlers, Two Sisters,...      NaN
# 1049                                                NaN      NaN
# 1050                                                NaN      NaN
# 1051                                                NaN      NaN
# 1052                                                NaN      NaN
# 1183                                                NaN      NaN
# 1248                                              cover      NaN
# 1260                                   Shelley Anderson      NaN
# 1267                                          Nett Hart      NaN
# 1270  Margaret Merrifield M.D.; Rosamund Elwin & Mic...      NaN
# 1439                         Compiled by Dawn L. Martin      NaN
# 1504                                                NaN      NaN
#
#               Graphics?                                              Notes  \
# 36                  NaN                                                NaN
# 37                  NaN                                                NaN
# 40                  NaN                                                NaN
# 41                  NaN                                                NaN
# 42                  NaN                                                NaN
# 43                  NaN                                                NaN
# 397                 yes  Image by Amy Reichert in Betty-san p.45; ditto...
# 471                 Yes                     Graphic: photo of damaged book
# 573   yes - book covers                                                NaN
# 759                 NaN                                                NaN
# 894                 NaN  1000 Booksellers Sign Petition Against Illegal...
# 1048                NaN                                                NaN
# 1049                NaN                                                NaN
# 1050                NaN                                                NaN
# 1051                NaN                                                NaN
# 1052                NaN                                                NaN
# 1183                NaN                                              cover
# 1248                NaN                                                NaN
# 1260                NaN                                                NaN
# 1267                yes  graphic of naked woman in a field of corn. gra...
# 1270                NaN                                                NaN
# 1439                 No                                                NaN
# 1504                NaN                                                NaN
#
#      File
# 36    NaN
# 37    NaN
# 40    NaN
# 41    NaN
# 42    NaN
# 43    NaN
# 397   NaN
# 471   NaN
# 573   NaN
# 759   NaN
# 894   NaN
# 1048  NaN
# 1049  NaN
# 1050  NaN
# 1051  NaN
# 1052  NaN
# 1183  NaN
# 1248  NaN
# 1260  NaN
# 1267  NaN
# 1270  NaN
# 1439  NaN
# 1504  NaN

# %%
#saving the bottom dataset as bottom_housing.csv
df.to_excel(r'C:\Users\salom\OneDrive\Área de Trabalho\FBN-\FBNClean.xlsx', index=False)
