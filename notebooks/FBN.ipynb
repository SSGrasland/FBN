# %%
#Importing libraries needed
import pandas as pd
import numpy as np

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#opening the datasets
df = pd.read_excel(r'C:\Users\salom\OneDrive\Área de Trabalho\FBN-\Feminist Bookstore News (1).xlsx')

# %%
df.head()
# Out:
#   ContributorName  Vol  No  Year    Month              ArticleTitle  \
# 0  Li-Anne Wright    1   1  1976  October  Mission/About Newsletter
# 1  Li-Anne Wright    1   1  1976  October            Editor's Note?
# 2  Li-Anne Wright    1   1  1976  October             Hot New Books
# 3  Li-Anne Wright    1   1  1976  October          Books in Spanish
# 4  Li-Anne Wright    1   1  1976  October           Brilliant Ideas
#
#    PageStart  PageEnd  ArticleLength  ArticlePercent  IssueLength  \
# 0        1.0      1.0            1.0            12.5          8.0
# 1        2.0      2.0            1.0            12.5          8.0
# 2        2.0      3.0            2.0            25.0          8.0
# 3        3.0      5.0            3.0            37.5          8.0
# 4        5.0      5.0            1.0            12.5          8.0
#
#          Author               Category Graphics?  \
# 0         Andre          Editor's Note       NaN
# 1  Carol Seajay          Editor's Note       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ContributorName  1564 non-null   object
#  1   Vol              1564 non-null   int64
#  2   No               1564 non-null   int64
#  3   Year             1564 non-null   int64
#  4   Month            1139 non-null   object
#  5   ArticleTitle     1552 non-null   object
#  6   PageStart        1555 non-null   float64
#  7   PageEnd          1521 non-null   float64
#  8   ArticleLength    1521 non-null   float64
#  9   ArticlePercent   1521 non-null   float64
#  10  IssueLength      1547 non-null   float64
#  11  Author           1407 non-null   object
#  12  Category         1549 non-null   object
#  13  Graphics?        986 non-null    object
#  14  Notes            924 non-null    object
#  15  File             3 non-null      object
# ...

# %%
df.isna().sum()
# Out:
# ContributorName       0
# Vol                   0
# No                    0
# Year                  0
# Month               425
# ArticleTitle         12
# PageStart             9
# PageEnd              43
# ArticleLength        43
# ArticlePercent       43
# IssueLength          17
# Author              157
# Category             15
# Graphics?           578
# Notes               640
# File               1561
# dtype: int64

# %%
df.dropna(subset = ['Vol', 'No', 'Year'], inplace=True)

# %%
df.isna().sum()
# Out:
# ContributorName       0
# Vol                   0
# No                    0
# Year                  0
# Month               425
# ArticleTitle         12
# PageStart             9
# PageEnd              43
# ArticleLength        43
# ArticlePercent       43
# IssueLength          17
# Author              157
# Category             15
# Graphics?           578
# Notes               640
# File               1561
# dtype: int64

# %%
df[['No', 'PageStart', 'PageEnd']] = df[['No', 'PageStart', 'PageEnd']].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ContributorName  1564 non-null   object
#  1   Vol              1564 non-null   int64
#  2   No               1564 non-null   int64
#  3   Year             1564 non-null   int64
#  4   Month            1139 non-null   object
#  5   ArticleTitle     1552 non-null   object
#  6   PageStart        1555 non-null   float64
#  7   PageEnd          1521 non-null   float64
#  8   ArticleLength    1521 non-null   float64
#  9   ArticlePercent   1521 non-null   float64
#  10  IssueLength      1547 non-null   float64
#  11  Author           1407 non-null   object
#  12  Category         1549 non-null   object
#  13  Graphics?        986 non-null    object
#  14  Notes            924 non-null    object
#  15  File             3 non-null      object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1564 entries, 0 to 1563
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ContributorName  1564 non-null   object
#  1   Vol              1564 non-null   int64
#  2   No               1564 non-null   int64
#  3   Year             1564 non-null   int64
#  4   Month            1139 non-null   object
#  5   ArticleTitle     1552 non-null   object
#  6   PageStart        1555 non-null   float64
#  7   PageEnd          1521 non-null   float64
#  8   ArticleLength    1521 non-null   float64
#  9   ArticlePercent   1521 non-null   float64
#  10  IssueLength      1547 non-null   float64
#  11  Author           1407 non-null   object
#  12  Category         1549 non-null   object
#  13  Graphics?        986 non-null    object
#  14  Notes            924 non-null    object
#  15  File             3 non-null      object
# ...

# %%
df['Issue Length'] = df.groupby(['Vol', 'No'])['PageEnd'].transform(max)

# %%
df
# Out:
#      ContributorName  Vol  No  Year    Month  \
# 0     Li-Anne Wright    1   1  1976  October
# 1     Li-Anne Wright    1   1  1976  October
# 2     Li-Anne Wright    1   1  1976  October
# 3     Li-Anne Wright    1   1  1976  October
# 4     Li-Anne Wright    1   1  1976  October
# ...              ...  ...  ..   ...      ...
# 1559  Li-Anne Wright   22   6  2000      NaN
# 1560  Li-Anne Wright   22   6  2000      NaN
# 1561  Li-Anne Wright   22   6  2000      NaN
# 1562  Li-Anne Wright   22   6  2000      NaN
# 1563  Li-Anne Wright   22   6  2000      NaN
#
#                              ArticleTitle  PageStart  PageEnd  ArticleLength  \
# 0                Mission/About Newsletter        1.0      1.0            1.0
# 1                          Editor's Note?        2.0      2.0            1.0
# 2                           Hot New Books        2.0      3.0            2.0
# 3                        Books in Spanish        3.0      5.0            3.0
# ...

# %%
df['ArticleLength'] = (df['PageEnd'] - df['PageStart']) + 1
df.head()
# Out:
#   ContributorName  Vol  No  Year    Month              ArticleTitle  \
# 0  Li-Anne Wright    1   1  1976  October  Mission/About Newsletter
# 1  Li-Anne Wright    1   1  1976  October            Editor's Note?
# 2  Li-Anne Wright    1   1  1976  October             Hot New Books
# 3  Li-Anne Wright    1   1  1976  October          Books in Spanish
# 4  Li-Anne Wright    1   1  1976  October           Brilliant Ideas
#
#    PageStart  PageEnd  ArticleLength  ArticlePercent  IssueLength  \
# 0        1.0      1.0            1.0            12.5          8.0
# 1        2.0      2.0            1.0            12.5          8.0
# 2        2.0      3.0            2.0            25.0          8.0
# 3        3.0      5.0            3.0            37.5          8.0
# 4        5.0      5.0            1.0            12.5          8.0
#
#          Author               Category Graphics?  \
# 0         Andre          Editor's Note       NaN
# 1  Carol Seajay          Editor's Note       NaN
# ...

# %%
df['ArticlePercent'] = (df['ArticleLength']/df['IssueLength'])*100

# %%
df.head()
# Out:
#   ContributorName  Vol  No  Year    Month              ArticleTitle  \
# 0  Li-Anne Wright    1   1  1976  October  Mission/About Newsletter
# 1  Li-Anne Wright    1   1  1976  October            Editor's Note?
# 2  Li-Anne Wright    1   1  1976  October             Hot New Books
# 3  Li-Anne Wright    1   1  1976  October          Books in Spanish
# 4  Li-Anne Wright    1   1  1976  October           Brilliant Ideas
#
#    PageStart  PageEnd  ArticleLength  ArticlePercent  IssueLength  \
# 0        1.0      1.0            1.0            12.5          8.0
# 1        2.0      2.0            1.0            12.5          8.0
# 2        2.0      3.0            2.0            25.0          8.0
# 3        3.0      5.0            3.0            37.5          8.0
# 4        5.0      5.0            1.0            12.5          8.0
#
#          Author               Category Graphics?  \
# 0         Andre          Editor's Note       NaN
# 1  Carol Seajay          Editor's Note       NaN
# ...

# %%
#commenting this out to run a new data 
'''
df['ArticleTitle'] = df['Article Title']
df['PageStart'] = df['Page Start'] 
df['PageEnd'] = df['Page End']
df['IssueLength'] = df['Issue Length']
df['ContributorName'] = df['Contributor Name']
df['Issue'] = df['No']
df.head()
'''
# Out:
# "\ndf['ArticleTitle'] = df['Article Title']\ndf['PageStart'] = df['Page Start'] \ndf['PageEnd'] = df['Page End']\ndf['IssueLength'] = df['Issue Length']\ndf['ContributorName'] = df['Contributor Name']\ndf['Issue'] = df['No']\ndf.head()\n"

# %%
df = df[['ContributorName', 'Vol', 'No', 'Year', 'Month', 'ArticleTitle', 'PageStart', 'PageEnd', 'ArticleLength', 'ArticlePercent', 'IssueLength', 'Author', 'Category', 'Graphics?', 'Notes', 'File']]
df.head()
# Out:
#   ContributorName  Vol  No  Year    Month              ArticleTitle  \
# 0  Li-Anne Wright    1   1  1976  October  Mission/About Newsletter
# 1  Li-Anne Wright    1   1  1976  October            Editor's Note?
# 2  Li-Anne Wright    1   1  1976  October             Hot New Books
# 3  Li-Anne Wright    1   1  1976  October          Books in Spanish
# 4  Li-Anne Wright    1   1  1976  October           Brilliant Ideas
#
#    PageStart  PageEnd  ArticleLength  ArticlePercent  IssueLength  \
# 0        1.0      1.0            1.0            12.5          8.0
# 1        2.0      2.0            1.0            12.5          8.0
# 2        2.0      3.0            2.0            25.0          8.0
# 3        3.0      5.0            3.0            37.5          8.0
# 4        5.0      5.0            1.0            12.5          8.0
#
#          Author               Category Graphics?  \
# 0         Andre          Editor's Note       NaN
# 1  Carol Seajay          Editor's Note       NaN
# ...

# %%
df.Month.unique()
# Out:
# array(['October', 'November', 'January', '?', 'June', 'August',
#        '(Sep/Oct?)', 'December', 'September', nan, 'May-June', 'Dec',
#        'Feb', 'April', 'Augusr', 'Nov/Dec.', 'Nov', 'Jan/Feb', 'Mar/Apr',
#        'May/June', 'Sept / Oct', 'Sept/Oct', 'March/April',
#        'November/December', 3], dtype=object)

# %%
#Unifying Month Values 
row_labels = {'(Sep/Oct?)':'September','May-June':'May', 'Dec':'December',
       'Feb':'February', 'Augusr':'August', 'Nov/Dec.':'November', 'Nov':'November', 'Jan/Feb':'January', 'Mar/Apr':'March',
       'May/June':'May', 'Sept / Oct':'September', 'Sept/Oct':'September', 'March/April':'March',
       'November/December':'November'}

df['Month']=df['Month'].replace(row_labels)
# Out:
# C:\Users\salom\AppData\Local\Temp\ipykernel_7332\1502239364.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Month']=df['Month'].replace(row_labels)

# %%
df.Month.unique()
# Out:
# array(['October', 'November', 'January', '?', 'June', 'August',
#        'September', 'December', nan, 'May', 'February', 'April', 'March',
#        3], dtype=object)

# %%
df.Category.unique()
# Out:
# array(["Editor's Note", 'Booklist/Medialist', 'Short News Bookstores',
#        'Other', 'Other Feature', 'Advertisements', 'Table of Contents',
#        'Letters', 'News Feature', 'Short News', nan,
#        'External Booklists and Awards', 'Short News Publishers',
#        'They Went That-A-Way', 'Letter ', 'Booklist/Media list',
#        'Workshop Summary', 'Presslist', 'Writing Wanted', 'Booklist'],
#       dtype=object)

# %%
row_labels = {'Other Feature' : 'Other', 'Letter ':'Letters', 'Booklist/Media list' : 'Booklist/Medialist', 'Booklist':'Booklist/Medialist'}

df['Category']=df['Category'].replace(row_labels)
# Out:
# C:\Users\salom\AppData\Local\Temp\ipykernel_7332\165856882.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Category']=df['Category'].replace(row_labels)

# %%
df.Category.unique()
# Out:
# array(["Editor's Note", 'Booklist/Medialist', 'Short News Bookstores',
#        'Other', 'Advertisements', 'Table of Contents', 'Letters',
#        'News Feature', 'Short News', nan, 'External Booklists and Awards',
#        'Short News Publishers', 'They Went That-A-Way',
#        'Workshop Summary', 'Presslist', 'Writing Wanted'], dtype=object)

# %%
df[df['Category'].isna()]
# Out:
#        ContributorName  Vol  No  Year     Month                  ArticleTitle  \
# 36         Rose Norman    2   1  1978         ?                 From the Boys
# 37         Rose Norman    2   1  1978         ?                   SciFi Notes
# 40         Rose Norman    2   1  1978         ?                    Used Books
# 41         Rose Norman    2   1  1978         ?              New Distributors
# 42         Rose Norman    2   1  1978         ?  Misc from the Questionnaires
# 43         Rose Norman    2   1  1978         ?                      Changing
# 278       Cassidy Hunt    8   4  1985       NaN            On Publisher's Row
# 661     Li-Anne Wright   10   6  1988     April                       Letters
# 796     Taylor Harding   11   4  1988  November                Short Stories
# 950       Rosal Lorico   12   1  1989       May                   Bestsellers
# 951       Rosal Lorico   12   1  1989       May                           NaN
# ...

# %%
#saving the bottom dataset as bottom_housing.csv
df.to_excel(r'C:\Users\salom\OneDrive\Área de Trabalho\FBN-\FBNClean.xlsx', index=False)
